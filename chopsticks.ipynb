# %%
# %load_ext autoreload
# %autoreload 2
import torch
from torch.utils.data import DataLoader, TensorDataset

from games.chopsticks import ChopsticksGame
from models.chopsticks import ChopsticksMLP
from sims.tree import MCTS
from utils import trainer

# %% [markdown]
# # Training

# %%
game = ChopsticksGame(draw_limit=30)
model = ChopsticksMLP(game.state_dim(), 64, game.num_actions())
mcts = MCTS(game, model, {'c_puct': 1.0, 'num_simulations': 1000})

# %%
num_games = 50
batch_size = 64
num_epochs = 50

# %%
samples = trainer.self_play(mcts, game, num_games)
dataloader = trainer.create_dataloader(samples, batch_size=batch_size)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
trainer.train_model(model, dataloader, optimizer, num_epochs)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [07:38<00:00,  9.18s/it]
# Epoch 1/50, Loss: 2.0744
# Epoch 2/50, Loss: 1.8088
# Epoch 3/50, Loss: 1.7233
# Epoch 4/50, Loss: 1.6321
# Epoch 5/50, Loss: 1.5915
# Epoch 6/50, Loss: 1.5983
# Epoch 7/50, Loss: 1.5207
# Epoch 8/50, Loss: 1.4463
# Epoch 9/50, Loss: 1.4862
# Epoch 10/50, Loss: 1.4853
# Epoch 11/50, Loss: 1.4596
# Epoch 12/50, Loss: 1.4306
# Epoch 13/50, Loss: 1.4320
# Epoch 14/50, Loss: 1.4452
# Epoch 15/50, Loss: 1.4008
# Epoch 16/50, Loss: 1.3922
# Epoch 17/50, Loss: 1.3867
# Epoch 18/50, Loss: 1.3929
# Epoch 19/50, Loss: 1.3830
# Epoch 20/50, Loss: 1.3599
# Epoch 21/50, Loss: 1.3442
# Epoch 22/50, Loss: 1.3310
# Epoch 23/50, Loss: 1.3395
# Epoch 24/50, Loss: 1.3140
# Epoch 25/50, Loss: 1.3153
# Epoch 26/50, Loss: 1.2832
# Epoch 27/50, Loss: 1.3442
# Epoch 28/50, Loss: 1.2909
# Epoch 29/50, Loss: 1.3028
# Epoch 30/50, Loss: 1.3121
# Epoch 31/50, Loss: 1.2680
# Epoch 32/50, Loss: 1.2829
# Epoch 33/50, Loss: 1.2760
# Epoch 34/50, Loss: 1.2895
# Epoch 35/50, Loss: 1.2990
# Epoch 36/50, Loss: 1.3024
# Epoch 37/50, Loss: 1.2155
# Epoch 38/50, Loss: 1.2549
# Epoch 39/50, Loss: 1.2674
# Epoch 40/50, Loss: 1.2403
# Epoch 41/50, Loss: 1.2452
# Epoch 42/50, Loss: 1.2259
# Epoch 43/50, Loss: 1.2111
# Epoch 44/50, Loss: 1.2145
# Epoch 45/50, Loss: 1.2010
# Epoch 46/50, Loss: 1.1924
# Epoch 47/50, Loss: 1.1774
# Epoch 48/50, Loss: 1.2054
# Epoch 49/50, Loss: 1.1953
# Epoch 50/50, Loss: 1.2147

# %%
trainer.train_model(model, dataloader, optimizer, num_epochs)
# Out:
# Epoch 1/50, Loss: 0.8329
# Epoch 2/50, Loss: 0.8134
# Epoch 3/50, Loss: 0.8129
# Epoch 4/50, Loss: 0.8371
# Epoch 5/50, Loss: 0.8101
# Epoch 6/50, Loss: 0.8170
# Epoch 7/50, Loss: 0.8148
# Epoch 8/50, Loss: 0.8173
# Epoch 9/50, Loss: 0.8192
# Epoch 10/50, Loss: 0.8143
# Epoch 11/50, Loss: 0.8013
# Epoch 12/50, Loss: 0.8031
# Epoch 13/50, Loss: 0.8149
# Epoch 14/50, Loss: 0.8001
# Epoch 15/50, Loss: 0.8349
# Epoch 16/50, Loss: 0.7954
# Epoch 17/50, Loss: 0.8040
# Epoch 18/50, Loss: 0.8041
# Epoch 19/50, Loss: 0.8168
# Epoch 20/50, Loss: 0.8267
# Epoch 21/50, Loss: 0.8008
# Epoch 22/50, Loss: 0.8088
# Epoch 23/50, Loss: 0.8420
# Epoch 24/50, Loss: 0.8129
# Epoch 25/50, Loss: 0.8388
# Epoch 26/50, Loss: 0.8095
# Epoch 27/50, Loss: 0.8310
# Epoch 28/50, Loss: 0.8234
# Epoch 29/50, Loss: 0.8340
# Epoch 30/50, Loss: 0.8113
# Epoch 31/50, Loss: 0.8235
# Epoch 32/50, Loss: 0.8172
# Epoch 33/50, Loss: 0.8279
# Epoch 34/50, Loss: 0.8413
# Epoch 35/50, Loss: 0.8338
# Epoch 36/50, Loss: 0.8187
# Epoch 37/50, Loss: 0.8214
# Epoch 38/50, Loss: 0.8081
# Epoch 39/50, Loss: 0.7940
# Epoch 40/50, Loss: 0.8273
# Epoch 41/50, Loss: 0.8083
# Epoch 42/50, Loss: 0.8052
# Epoch 43/50, Loss: 0.8005
# Epoch 44/50, Loss: 0.7985
# Epoch 45/50, Loss: 0.8265
# Epoch 46/50, Loss: 0.8080
# Epoch 47/50, Loss: 0.7973
# Epoch 48/50, Loss: 0.8001
# Epoch 49/50, Loss: 0.7964
# Epoch 50/50, Loss: 0.7916

# %%
game.reset()
node = mcts.run(game.state)
node.children
# Out:
# {0: tensor([1., 1., 2., 1., 1., 1.]) Prior: 0.02 Count: 1 Value: tensor([0.8859]),
#  1: tensor([1., 1., 1., 2., 1., 1.]) Prior: 0.00 Count: 1 Value: tensor([0.7036]),
#  2: tensor([1., 2., 1., 1., 1., 1.]) Prior: 0.90 Count: 974 Value: tensor([-0.1474]),
#  3: tensor([1., 1., 2., 1., 1., 1.]) Prior: 0.02 Count: 1 Value: tensor([0.8859]),
#  4: tensor([1., 1., 1., 2., 1., 1.]) Prior: 0.00 Count: 1 Value: tensor([0.7036]),
#  5: tensor([2., 1., 1., 1., 1., 1.]) Prior: 0.06 Count: 22 Value: tensor([-0.0011])}

# %%
game.reset()
game_continues = True
while game_continues:
    game.print_state(game.state)
    root = mcts.run(game.state)
    print(f"Action probabilities:{root.action_probs()}")
    action = root.sample_action()  # sample action according to visit counts
    # action = root.best_action()  # choose the most visited action
    game_continues = game.play(action)
    print(f"Action taken:{game.describe_action(action)}")
    print("-" * 30)
    if not game_continues:
        game.print_state(game.state)
        reward = game.reward(game.state)
        if reward == 0:
            print("It's a draw!")
        else:
            winner = 1 - game.state[-1]
            print(f"Player {int(winner + 1)} wins!")
        print("Game over.")
# Out:
#   Rounds Played: 0
#   P1: Left=1, Right=1
#   P2: Left=1, Right=1
#   Current Player: P1
# Action probabilities:{0: 0.001, 1: 0.001, 2: 0.974, 3: 0.001, 4: 0.001, 5: 0.022}
# Action taken:Current left hand taps current right hand
# ------------------------------
#
#   Rounds Played: 1
#   P1: Left=1, Right=2
#   P2: Left=1, Right=1
#   Current Player: P2
# Action probabilities:{0: 0.001, 1: 0.591, 2: 0.143, 3: 0.001, 4: 0.217, 5: 0.047}
# Action taken:Current right hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 2
#   P1: Left=1, Right=3
#   P2: Left=1, Right=1
#   Current Player: P1
# Action probabilities:{0: 0.001, 1: 0.0, 2: 0.0, 3: 0.015, 4: 0.001, 5: 0.065, 7: 0.918}
# Action taken:Split fingers: left hand gets 2 fingers
# ------------------------------
#
#   Rounds Played: 3
#   P1: Left=2, Right=2
#   P2: Left=1, Right=1
#   Current Player: P2
# Action probabilities:{0: 0.002, 1: 0.001, 2: 0.001, 3: 0.005, 4: 0.001, 5: 0.99}
# Action taken:Current right hand taps current left hand
# ------------------------------
#
#   Rounds Played: 4
#   P1: Left=2, Right=2
#   P2: Left=2, Right=1
#   Current Player: P1
# Action probabilities:{0: 0.992, 1: 0.001, 2: 0.0, 3: 0.005, 4: 0.0, 5: 0.001, 6: 0.0, 8: 0.001}
# Action taken:Current left hand taps opponent's left hand
# ------------------------------
#
#   Rounds Played: 5
#   P1: Left=2, Right=2
#   P2: Left=4, Right=1
#   Current Player: P2
# Action probabilities:{0: 0.008, 1: 0.007, 2: 0.001, 3: 0.002, 4: 0.001, 5: 0.001, 7: 0.706, 8: 0.274}
# Action taken:Split fingers: left hand gets 2 fingers
# ------------------------------
#
#   Rounds Played: 6
#   P1: Left=2, Right=2
#   P2: Left=2, Right=3
#   Current Player: P1
# Action probabilities:{0: 0.001, 1: 0.214, 2: 0.0, 3: 0.001, 4: 0.783, 5: 0.001, 6: 0.0, 8: 0.0}
# Action taken:Current right hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 7
#   P1: Left=2, Right=2
#   P2: Left=2, Right=0
#   Current Player: P2
# Action probabilities:{0: 0.001, 1: 0.001, 6: 0.998}
# Action taken:Split fingers: left hand gets 1 finger
# ------------------------------
#
#   Rounds Played: 8
#   P1: Left=2, Right=2
#   P2: Left=1, Right=1
#   Current Player: P1
# Action probabilities:{0: 0.001, 1: 0.018, 2: 0.008, 3: 0.0, 4: 0.0, 5: 0.003, 6: 0.0, 8: 0.97}
# Action taken:Split fingers: left hand gets 3 fingers
# ------------------------------
#
#   Rounds Played: 9
#   P1: Left=3, Right=1
#   P2: Left=1, Right=1
#   Current Player: P2
# Action probabilities:{0: 0.049, 1: 0.938, 2: 0.004, 3: 0.006, 4: 0.001, 5: 0.002}
# Action taken:Current left hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 10
#   P1: Left=3, Right=2
#   P2: Left=1, Right=1
#   Current Player: P1
# Action probabilities:{0: 0.379, 1: 0.313, 2: 0.304, 3: 0.0, 4: 0.004, 5: 0.0, 6: 0.0, 9: 0.0}
# Action taken:Current left hand taps current right hand
# ------------------------------
#
#   Rounds Played: 11
#   P1: Left=3, Right=0
#   P2: Left=1, Right=1
#   Current Player: P2
# Action probabilities:{0: 0.992, 2: 0.005, 3: 0.002, 5: 0.001}
# Action taken:Current left hand taps opponent's left hand
# ------------------------------
#
#   Rounds Played: 12
#   P1: Left=4, Right=0
#   P2: Left=1, Right=1
#   Current Player: P1
# Action probabilities:{0: 0.002, 1: 0.001, 6: 0.98, 7: 0.017, 8: 0.0}
# Action taken:Split fingers: left hand gets 1 finger
# ------------------------------
#
#   Rounds Played: 13
#   P1: Left=1, Right=3
#   P2: Left=1, Right=1
#   Current Player: P2
# Action probabilities:{0: 0.013, 1: 0.076, 2: 0.004, 3: 0.824, 4: 0.076, 5: 0.007}
# Action taken:Current right hand taps opponent's left hand
# ------------------------------
#
#   Rounds Played: 14
#   P1: Left=2, Right=3
#   P2: Left=1, Right=1
#   Current Player: P1
# Action probabilities:{0: 0.414, 1: 0.22, 2: 0.218, 3: 0.001, 4: 0.144, 5: 0.003, 6: 0.0, 9: 0.0}
# Action taken:Current left hand taps opponent's left hand
# ------------------------------
#
#   Rounds Played: 15
#   P1: Left=2, Right=3
#   P2: Left=3, Right=1
#   Current Player: P2
# Action probabilities:{0: 0.007, 1: 0.823, 2: 0.096, 3: 0.003, 4: 0.004, 5: 0.001, 7: 0.066}
# Action taken:Current left hand taps current right hand
# ------------------------------
#
#   Rounds Played: 16
#   P1: Left=2, Right=3
#   P2: Left=3, Right=4
#   Current Player: P1
# Action probabilities:{0: 0.001, 1: 0.993, 2: 0.001, 3: 0.001, 4: 0.001, 5: 0.001, 6: 0.001, 9: 0.001}
# Action taken:Current left hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 17
#   P1: Left=2, Right=3
#   P2: Left=3, Right=0
#   Current Player: P2
# Action probabilities:{0: 0.001, 1: 0.007, 6: 0.256, 7: 0.736}
# Action taken:Split fingers: left hand gets 2 fingers
# ------------------------------
#
#   Rounds Played: 18
#   P1: Left=2, Right=3
#   P2: Left=2, Right=1
#   Current Player: P1
# Action probabilities:{0: 0.032, 1: 0.007, 2: 0.001, 3: 0.951, 4: 0.004, 5: 0.001, 6: 0.001, 9: 0.003}
# Action taken:Current right hand taps opponent's left hand
# ------------------------------
#
#   Rounds Played: 19
#   P1: Left=2, Right=3
#   P2: Left=0, Right=1
#   Current Player: P2
# Action probabilities:{3: 0.931, 4: 0.069}
# Action taken:Current right hand taps opponent's left hand
# ------------------------------
#
#   Rounds Played: 20
#   P1: Left=3, Right=3
#   P2: Left=0, Right=1
#   Current Player: P1
# Action probabilities:{1: 0.994, 2: 0.0, 4: 0.006, 5: 0.0, 7: 0.0, 9: 0.0}
# Action taken:Current left hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 21
#   P1: Left=3, Right=3
#   P2: Left=0, Right=4
#   Current Player: P2
# Action probabilities:{3: 0.001, 4: 0.115, 6: 0.001, 7: 0.871, 8: 0.012}
# Action taken:Split fingers: left hand gets 2 fingers
# ------------------------------
#
#   Rounds Played: 22
#   P1: Left=3, Right=3
#   P2: Left=2, Right=2
#   Current Player: P1
# Action probabilities:{0: 0.474, 1: 0.153, 2: 0.0, 3: 0.22, 4: 0.153, 5: 0.0, 7: 0.0, 9: 0.0}
# Action taken:Current right hand taps opponent's left hand
# ------------------------------
#
#   Rounds Played: 23
#   P1: Left=3, Right=3
#   P2: Left=0, Right=2
#   Current Player: P2
# Action probabilities:{3: 0.029, 4: 0.117, 6: 0.854}
# Action taken:Split fingers: left hand gets 1 finger
# ------------------------------
#
#   Rounds Played: 24
#   P1: Left=3, Right=3
#   P2: Left=1, Right=1
#   Current Player: P1
# Action probabilities:{0: 0.195, 1: 0.609, 2: 0.001, 3: 0.17, 4: 0.025, 5: 0.0, 7: 0.0, 9: 0.0}
# Action taken:Current right hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 25
#   P1: Left=3, Right=3
#   P2: Left=1, Right=4
#   Current Player: P2
# Action probabilities:{0: 0.001, 1: 0.82, 2: 0.005, 3: 0.091, 4: 0.058, 5: 0.001, 7: 0.001, 8: 0.023}
# Action taken:Current left hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 26
#   P1: Left=3, Right=4
#   P2: Left=1, Right=4
#   Current Player: P1
# Action probabilities:{0: 0.002, 1: 0.251, 2: 0.0, 3: 0.172, 4: 0.575, 5: 0.0}
# Action taken:Current right hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 27
#   P1: Left=3, Right=4
#   P2: Left=1, Right=0
#   Current Player: P2
# Action probabilities:{0: 0.017, 1: 0.983}
# Action taken:Current left hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 28
#   P1: Left=3, Right=0
#   P2: Left=1, Right=0
#   Current Player: P1
# Action probabilities:{0: 0.016, 6: 0.983, 7: 0.001}
# Action taken:Split fingers: left hand gets 1 finger
# ------------------------------
#
#   Rounds Played: 29
#   P1: Left=1, Right=2
#   P2: Left=1, Right=0
#   Current Player: P2
# Action probabilities:{0: 0.176, 1: 0.824}
# Action taken:Current left hand taps opponent's right hand
# ------------------------------
#
#   Rounds Played: 30
#   P1: Left=1, Right=3
#   P2: Left=1, Right=0
#   Current Player: P1
# It's a draw!
# Game over.

# %% [markdown]
# # Testing

# %%
game = ChopsticksGame()
game.test_get_next_state()

# %%
game.test_get_legal_actions()

# %%
game.test_reward()
